# %% [markdown]
# ## Email Crawler
#
# To get started, we don't have to install anything. All the modules used in this tutorial are the built-in ones:

# %%
import imaplib
import email
from email.header import decode_header
import webbrowser
import os
import re # I need this package to filter particular text-patterns in my emails. --> Note: it is already built-in!
import pandas as pd # to create the Dataframes at the end

# account credentials
username = "my.email@example.com" # <-- Place your email-account that you want to scrape in here. I deleted my credentials, since you should NEVER push them to Github!
password = "Your_Email_Password" # <-- Paste in your email-password here. I deleted my credentials, since you should NEVER push them to Github!
# use your email provider's IMAP server, you can look for your provider's IMAP server on Google
# or check this page: https://www.systoolsgroup.com/imap/
# for hotmail, it's this:
imap_server = "imap-mail.outlook.com" # checkout this link for other email-servers: https://www.systoolsgroup.com/imap/

def clean(text):
    # clean text for creating a folder
    return "".join(c if c.isalnum() else "_" for c in text)

# %% [markdown]
# - <u>Link to other Email Servers</u>: https://www.systoolsgroup.com/imap/
# - <u>Note</u>: We will need the `clean()`-function later to create folders without spaces and special characters (= e.g. an NLP-technique to clean text-based data).

# %% [markdown]
# ### 1) Establish a connection to the Email-Server

# %%
# create an IMAP4 class with SSL 
imap = imaplib.IMAP4_SSL(imap_server)
# authenticate
imap.login(username, password)
# Out:
# ('OK', [b'LOGIN completed.'])

# %% [markdown]
# ### 2) Get <u>all</u> the Emails from the "Jobs"-Folder

# %%
status, messages = imap.select("Jobs")

# number of emails to fetch (from the "top" - e.g. the most recent - to the "bottom"...)
N = 234 # <-- Key: Modify THIS bit to get the correct total of emails in your inbox!

# "messages" will contain the total number of emails in the folder "Jobs"
messages = int(messages[0])
print(messages) # check, if it worked? --> we see that we currently have 232 emails in the folder "Jobs"
# Out:
# 234

# %% [markdown]
# - <u>Exploration of your Mail-Box's Folders</u>: You can use the `imap.list()` method to see the available mailboxes.

# %%
imap.list()
# Out:
# ('OK',
#  [b'(\\HasNoChildren) "/" Archiv',
#   b'(\\HasNoChildren \\Drafts) "/" Drafts',
#   b'(\\HasChildren \\Trash) "/" Deleted',
#   b'(\\HasNoChildren \\Sent) "/" Sent',
#   b'(\\HasChildren) "/" Jobs',
#   b'(\\HasNoChildren \\Junk) "/" Junk',
#   b'(\\HasNoChildren) "/" Notes',
#   b'(\\HasNoChildren) "/" Outbox',
#   b'(\\Marked \\HasNoChildren) "/" Inbox',
#   b'(\\HasChildren) "/" Synchronisierungsprobleme',
#   b'(\\HasNoChildren) "/" Synchronisierungsprobleme/Konflikte',
#   b'(\\HasNoChildren) "/" "Synchronisierungsprobleme/Lokale Fehler"',
#   b'(\\HasNoChildren) "/" Synchronisierungsprobleme/Serverfehler'])

# %% [markdown]
# ### 3) Read some emails from our "Jobs"-Folder

# %% [markdown]
# In the next 2 cells, **I will construct a time series dataset**.
#
# <u>This dataset will</u>:
#
# - Capture the **dynamics (over time) of entry-position jobs in the Swiss jobmarket for graduate economics & data science students**.
# - Track the number of _new_ open position each day in the Swiss jobmarket.
#
# _Note that the data I collected was generated by an algorithm that is provided by one of the biggest digital Swiss job-portals_.

# %%
dict_for_df = dict() # this empty dictionary will be transformed into the final time series ds later...
dates_array = [] # this will be my column "Date" in my later ds
total_jobs_available_today_array = [] # will be my column "Total Jobs available Today" 
new_jobs_today_array = [] # will be my column "New Jobs published Today"

### For 2nd DF:
dict_for_df2 = dict()
urls_array = [] # will be a list of lists (with an index of 5 --> this is KEY, because we need it to have the same length as the dates, since the dates will be our "observations"-unit in the DF2!)
job_titles_array = [] # same as "urls_array"...
companies_array = [] # same as "urls_array"...

# %%
for i in range(messages, messages-N, -1): # Why do we do this weird "backward"-loop? --> we want to iterate from the top to the bottom 
    # Key: in order to go "forward in time" (starting in the distant past), we need to iterate by typing in the 
    # following parameters: `messages-N, messages+1` and leave out "-1"(!!) at the end as the 3rd // last argument...
    # Backwards would be: `range(messages, messages-N, -1)`
    # fetch the email message by ID
    print("Currently reading {0}-th Email...".format(i))
    res, msg = imap.fetch(str(i), "(RFC822)") # `RFC822` is a special format that we can use to fetch the emails from the server: https://www.rfc-editor.org/rfc/rfc822
    for response in msg:
        if isinstance(response, tuple):
            msg = email.message_from_bytes(response[1]) # parse the bytes returned by the `fetch()`-method to a proper "Message"-object
            subject, encoding = decode_header(msg["Subject"])[0] # decode the "subject" of the email-address to human-readable Unicode.
            if isinstance(subject, bytes): # if the "subject" is from the data-type "bytes", decode to str
                subject = subject.decode(encoding)
            From, encoding = decode_header(msg.get("From"))[0] # decode email-sender (= "From") of the email-address to human-readable Unicode.
            if isinstance(From, bytes): # if the sender (= "From") is from the data-type "bytes", decode to str
                From = From.decode(encoding)
            print("Subject:", subject)
            print("From:", From)
            print(msg['Date'])
            todays_email_date = msg['Date']
            dates_array.append(todays_email_date) # append the dates to my empty array
            # if the email message is "multipart":  for instance, an email message can contain the "text/html"-content AND "text/plain"-parts, e.g. it has the HTML and(!) plain text versions of the message.
            if msg.is_multipart():
                # iterate over email parts
                for part in msg.walk():
                    # extract content type of email
                    content_type = part.get_content_type()
                    content_disposition = str(part.get("Content-Disposition"))
                    try:
                        # get the email body
                        body = part.get_payload(decode=True).decode()
                        lines = body.split('\n')
                        job_titles = []
                        companies = []
                        for line in lines:
                            if "https://www.jobs.ch/de/stellenangebote/detail/" in line:
                                job_titles.append(lines[lines.index(line) - 2])
                                companies.append(lines[lines.index(line) - 1])
                        matches_plural = re.findall(r".*neue Jobs.*", body)
                        matches_singular = re.findall(r".*neuer Job.*", body)
                        matches = matches_singular + matches_plural # concatenate the 2 lists into 1 (bigger) list
                        new_jobs_per_day = list(map(lambda string: int(string[0:2]), matches)) # take only the first element of each string (= which is the "number" - currently given as a `string` - that we are interested in, in order to calculate the total number of new open job position that opened "today")
                        total_new_jobs_today = sum(new_jobs_per_day)
                        urls = re.findall(r"https://www.jobs.ch/de/stellenangebote/detail/\S+", body)
                        currently_open_job_positions = len(urls)
                        total_jobs_available_today_array.append(currently_open_job_positions) 
                        new_jobs_today_array.append(total_new_jobs_today)
                        #print(matches)
                        #print(new_jobs_per_day)
                        #print(currently_open_job_positions)
                        #print(total_new_jobs_today)
                        #print(urls)
                        urls_array.append(urls)
                        #print(len(urls))
                        #print(job_titles)
                        job_titles_array.append(job_titles)
                        #print(len(job_titles))
                        #print(companies)
                        companies_array.append(companies)
                        #print(len(companies))
                        #print(body)
                        #print(matches_singular)
                        #print(matches_plural)
                    except:
                        pass
                    #if content_type == "text/plain" and "attachment" not in content_disposition:
                        # print text/plain emails and skip attachments
                        #print(body)
                    if "attachment" in content_disposition: # vorher: `elif` (statt `if`!)
                        # download attachment
                        filename = part.get_filename()
                        if filename:
                            folder_name = clean(subject)
                            if not os.path.isdir(folder_name):
                                # make a folder for this email (named after the subject)
                                os.mkdir(folder_name)
                            filepath = os.path.join(folder_name, filename)
                            # download attachment and save it
                            open(filepath, "wb").write(part.get_payload(decode=True))
            else:
                # extract content type of email
                content_type = msg.get_content_type()
                # get the email body
                body = msg.get_payload(decode=True).decode()
                #if content_type == "text/plain":
                    # print only text email parts
                    #print(body)
            #if content_type == "text/html":
                # if it's HTML, create a new HTML file and open it in browser
                #folder_name = clean(subject)
                #if not os.path.isdir(folder_name):
                    # make a folder for this email (named after the subject)
                    #os.mkdir(folder_name)
                #filename = "index.html"
                #filepath = os.path.join(folder_name, filename)
                # write the file
                #open(filepath, "w").write(body)
                # open in the default browser
                #webbrowser.open(filepath)
            print("="*100)
dict_for_df['Date'] = dates_array
dict_for_df['Total of open Job-Positions up until today'] = total_jobs_available_today_array
dict_for_df['New Jobs published Today'] = new_jobs_today_array

### 2nd DF:
for (date, url, title, company) in zip(dates_array, urls_array,  job_titles_array, companies_array):
    dict_for_df2[date] = [url, title, company] # this will add new keys to the dictionary, where the 'dates' are the keys and a list (of sublists, containing the URLs, Job-Titles and Company-Names) as the values...
# Out:
# Currently reading 234-th Email...
# Subject: 59 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Wed, 4 Jan 2023 06:16:14 +0000
# ====================================================================================================
# Currently reading 233-th Email...
# Subject: 8 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Tue, 3 Jan 2023 05:51:23 +0000
# ====================================================================================================
# Currently reading 232-th Email...
# Subject: 17 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Mon, 2 Jan 2023 05:50:05 +0000
# ====================================================================================================
# Currently reading 231-th Email...
# Subject: 40 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sat, 31 Dec 2022 05:57:44 +0000
# ====================================================================================================
# Currently reading 230-th Email...
# Subject: 34 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Wed, 28 Dec 2022 06:10:27 +0000
# ====================================================================================================
# Currently reading 229-th Email...
# Subject: 36 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Thu, 29 Dec 2022 05:55:44 +0000
# ====================================================================================================
# Currently reading 228-th Email...
# Subject: 24 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Fri, 30 Dec 2022 05:55:41 +0000
# ====================================================================================================
# Currently reading 227-th Email...
# Subject: 96 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sat, 24 Dec 2022 06:09:48 +0000
# ====================================================================================================
# Currently reading 226-th Email...
# Subject: 24 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sun, 25 Dec 2022 05:46:31 +0000
# ====================================================================================================
# Currently reading 225-th Email...
# Subject: 12 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Mon, 26 Dec 2022 05:39:22 +0000
# ====================================================================================================
# Currently reading 224-th Email...
# Subject: 60 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Fri, 23 Dec 2022 06:06:49 +0000
# ====================================================================================================
# Currently reading 223-th Email...
# Subject: 45 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Thu,
neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Tue, 17 May 2022 05:56:08 +0000
# ====================================================================================================
# Currently reading 23-th Email...
# Subject: 51 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Wed, 18 May 2022 06:04:46 +0000
# ====================================================================================================
# Currently reading 22-th Email...
# Subject: 12 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sun, 15 May 2022 05:38:58 +0000
# ====================================================================================================
# Currently reading 21-th Email...
# Subject: 70 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sat, 14 May 2022 05:58:08 +0000
# ====================================================================================================
# Currently reading 20-th Email...
# Subject: 55 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Tue, 10 May 2022 05:56:44 +0000
# ====================================================================================================
# Currently reading 19-th Email...
# Subject: 55 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Fri, 13 May 2022 05:56:26 +0000
# ====================================================================================================
# Currently reading 18-th Email...
# Subject: 170 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Thu, 12 May 2022 05:57:00 +0000
# ====================================================================================================
# Currently reading 17-th Email...
# Subject: 98 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Wed, 11 May 2022 06:05:04 +0000
# ====================================================================================================
# Currently reading 16-th Email...
# Subject: 60 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Fri, 6 May 2022 05:57:21 +0000
# ====================================================================================================
# Currently reading 15-th Email...
# Subject: 8 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sun, 8 May 2022 05:37:32 +0000
# ====================================================================================================
# Currently reading 14-th Email...
# Subject: 75 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sat, 7 May 2022 05:58:29 +0000
# ====================================================================================================
# Currently reading 13-th Email...
# Subject: 94 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Thu, 5 May 2022 05:54:57 +0000
# ====================================================================================================
# Currently reading 12-th Email...
# Subject: 73 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Wed, 4 May 2022 06:02:06 +0000
# ====================================================================================================
# Currently reading 11-th Email...
# Subject: 70 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Tue, 3 May 2022 05:58:13 +0000
# ====================================================================================================
# Currently reading 10-th Email...
# Subject: 28 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sun, 1 May 2022 05:41:25 +0000
# ====================================================================================================
# Currently reading 9-th Email...
# Subject: 12 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Mon, 2 May 2022 05:40:06 +0000
# ====================================================================================================
# Currently reading 8-th Email...
# Subject: 88 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sat, 30 Apr 2022 05:58:05 +0000
# ====================================================================================================
# Currently reading 7-th Email...
# Subject: 40 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Fri, 29 Apr 2022 05:57:36 +0000
# ====================================================================================================
# Currently reading 6-th Email...
# Subject: 57 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Thu, 28 Apr 2022 05:56:28 +0000
# ====================================================================================================
# Currently reading 5-th Email...
# Subject: 40 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Tue, 26 Apr 2022 06:01:01 +0000
# ====================================================================================================
# Currently reading 4-th Email...
# Subject: 13 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Mon, 25 Apr 2022 05:38:28 +0000
# ====================================================================================================
# Currently reading 3-th Email...
# Subject: 82 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sat, 23 Apr 2022 07:32:35 +0000
# ====================================================================================================
# Currently reading 2-th Email...
# Subject: 8 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sun, 24 Apr 2022 07:05:07 +0000
# ====================================================================================================
# Currently reading 1-th Email...
# Subject: Bewerbungsinfos
# From: Mayer Joffrey SBB CFF FFS <joffrey.mayer@sbb.ch>
# Mon, 1 Nov 2021 07:04:45 +0000
# ====================================================================================================

# %% [markdown]
# - <u>Note</u>: If you want to extract the oldest email addresses, you need to change the loop to something like `range(N)`.
#
# <u>Next, I will create a **second dataframe**, whose purpose will be</u>:
#
# - To collect the **URLs** that redirect to the currently open job-application,
# - As well as the corresponding **job-title** & **company name**,
# - And the job's **publishing-date**.

# %%
print(len(urls_array))
print(len(job_titles_array))
print(len(companies_array))
# Out:
# 234
# 234
# 234

# %%
msg.keys() # see available email-fields from which you can extract data.

# %% [markdown]
# ### 4) Create your DataFrames
#
# First, let's create the **time series dataset**, _where the "Date"-column serves as a **unique ID**_.

# %%
df = pd.DataFrame(dict_for_df)
df

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by="Date", inplace=True) # reverse the order of the DF (currently the "newest" date is in the front --> bring it into the back)

# %%
df

# %% [markdown]
# #### Create the 2nd DataFrame

# %%
# Create the dataframe
rows = []
for key, values in dict_for_df2.items():
    for value in values:
        row = {key: value}
        rows.append(row)

list_of_df = []
for i in rows:
    df2 = pd.DataFrame(i)
    list_of_df.append(df2)

# Problem in all the DFs? --> we have the Date as 1 column, instead of rows... --> Solution: transform the DF into "long-format"...
test = list_of_df[1]
test.stack().droplevel(level=0).to_frame().rename({0: 'Job Title'}, axis='columns') # Key: 'droplevel'-method, because I had an unnecessary multi-index...  

url_series = pd.Series()
#all_series = pd.Series()
# Transform all the DFs for the column 'URL':
for i in list_of_df[0::3]: # Key: we start with the 1st list-element of 'list_of_df' and then only iterate over every 3rd elements
    url_series = pd.concat([url_series, i.stack().droplevel(level=0)])
    
title_series = pd.Series()
# Transform all the DFs for the column 'URL':
for i in list_of_df[1::3]: # Key: we start with the 1st list-element of 'list_of_df' and then only iterate over every 3rd elements
    title_series = pd.concat([title_series, i.stack().droplevel(level=0)])
    
company_series = pd.Series()
# Transform all the DFs for the column 'URL':
for i in list_of_df[2::3]: # Key: we start with the 1st list-element of 'list_of_df' and then only iterate over every 3rd elements
    company_series = pd.concat([company_series, i.stack().droplevel(level=0)])
    
#for i in list_of_df[0::3]: # Key: we start with the 1st list-element of 'list_of_df' and then only iterate over every 3rd elements
#    all_series = pd.concat([all_series, i.stack().droplevel(level=0)])
#    for j in list_of_df[1::3]: # Key: we start with the 1st list-element of 'list_of_df' and then only iterate over every 3rd elements
#        all_series = pd.concat([all_series, j.stack().droplevel(level=0)])
#        for k in list_of_df[2::3]: # Key: we start with the 1st list-element of 'list_of_df' and then only iterate over every 3rd elements
#            all_series = pd.concat([all_series, k.stack().droplevel(level=0)])

url_df = url_series.to_frame().rename({0: 'url'}, axis='columns').reset_index().rename({'index': 'Date'}, axis='columns')
title_df = title_series.to_frame().rename({0: 'Job Title'}, axis='columns').reset_index().rename({'index': 'Date'}, axis='columns')
company_df = company_series.to_frame().rename({0: 'Employer Company'}, axis='columns').reset_index().rename({'index': 'Date'}, axis='columns')

url_df['Date'] = pd.to_datetime(url_df['Date'])
title_df['Date'] = pd.to_datetime(title_df['Date'])
company_df['Date'] = pd.to_datetime(company_df['Date'])
# Out:
# <ipython-input-7-919b711d270c>:17: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   url_series = pd.Series()
# <ipython-input-7-919b711d270c>:23: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   title_series = pd.Series()
# <ipython-input-7-919b711d270c>:28: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   company_series = pd.Series()

# %%
len(list_of_df) # check: I crawled 5 of my emails, where I needed data on 3 columns FOR EACH email 
# Hence - for each date - I should have: "3 (col) * 5 (emails // dates) = 15" sub-lists of data in total ? --> yes!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-bfdd4bab6ede> in <module>
# ----> 1 len(list_of_df) # check: I crawled 5 of my emails, where I needed data on 3 columns FOR EACH email
#       2 # Hence - for each date - I should have: "3 (col) * 5 (emails // dates) = 15" sub-lists of data in total ? --> yes!
#
# NameError: name 'list_of_df' is not defined

# %%
# Merging...
noob = pd.merge(
    url_df,
    title_df,
    how="left",
    on=url_df.index, # Key: we merge via the Index, which are only numbers from 0-184 --> merging via index. Note that I needed to put the "Date" as a column (and NOT as an index!)
).drop(['key_0', 'Date_y'], axis = 1) # we only need one of the "Date"-Columns. Also, we can drop the automatically generated column "key_0", which is a leftover-column that gets generated, because we merged via the "index". 

# second merge, since we need to combine 3 DFs into 1 "big" DF --> we currently only merged 2 (out of 3) DFs, that's why we need this 2nd merging...
noob = pd.merge(
    noob,
    company_df,
    how="left",
    on=noob.index, # Key: Again, we merge via the Index, which are ALL our observations...
).drop(['key_0', 'Date_x'], axis = 1)#.set_index('Date') # same as first merging: we drop one of the "Date"-Columns, as well as the automatically generated "index"-column (= 'key_0')... 

df2 = noob.sort_values(by="Date", ascending = False)
df2 = df2.reindex(columns=['Date', 'url', 'Job Title', 'Employer Company']) # change the order of columns: i want "date"-col to be the first one...

df2['Job Title'] = [el.replace("\r", "") for el in df2['Job Title']] # we need to remove the "\r" behind all the elements of the col of "Job Title" & "Employer Company", otherwise saving the ds correctly will not be possible! xD
df2['Employer Company'] = [el.replace("\r", "") for el in df2['Employer Company']] # same as above

# %%
df2 = df2.reset_index().drop(['index'], axis = 1)

# %% [markdown]
# ### 5) Save the generated DataFrame

# %%
df.to_csv('../data/jobs-over-time.csv', index=False)

# %%
df2.to_csv('../data/job-urls.csv', index=False)
df2.to_json('../data/job-urls.json')

# %%
df2
# Out:
#                           Date  \
# 0    2023-01-04 06:16:14+00:00
# 1    2023-01-04 06:16:14+00:00
# 2    2023-01-04 06:16:14+00:00
# 3    2023-01-04 06:16:14+00:00
# 4    2023-01-04 06:16:14+00:00
# ...                        ...
# 9718 2021-11-01 07:04:45+00:00
# 9719 2021-11-01 07:04:45+00:00
# 9720 2021-11-01 07:04:45+00:00
# 9721 2021-11-01 07:04:45+00:00
# 9722 2021-11-01 07:04:45+00:00
#
#                                                     url  \
# 0     https://www.jobs.ch/de/stellenangebote/detail/...
# 1     https://www.jobs.ch/de/stellenangebote/detail/...
# 2     https://www.jobs.ch/de/stellenangebote/detail/...
# 3     https://www.jobs.ch/de/stellenangebote/detail/...
# 4     https://www.jobs.ch/de/stellenangebote/detail/...
# ...                                                 ...
# 9718  https://www.jobs.ch/de/stellenangebote/detail/...
# 9719  https://www.jobs.ch/de/stellenangebote/detail/...
# 9720  https://www.jobs.ch/de/stellenangebote/detail/...
# 9721  https://www.jobs.ch/de/stellenangebote/detail/...
# 9722  https://www.jobs.ch/de/stellenangebote/detail/...
#
#                                               Job Title  \
# 0     Data Scientist - Optimierung Filialperformance...
# 1              Praktikant/in Backoffice 100% [Ref:1785]
# 2     Salesforce Consulting Trainee at a leading Men...
# 3        Praktikum im Bereich Manufacturing Engineering
# 4     Internship in Sterilization and Contamination ...
# ...                                                 ...
# 9718  Praktikant:in Social Media und Community SRF News
# 9719  Initial Training Academy (ATCO) Instructor: AC...
# 9720  Praktikant:in Social Media und Community SRF News
# 9721  Aktuar oder Ökonom in der Versicherungsaufsich...
# 9722                                 Engineer/Scientist
#
#                                     Employer Company
# 0                Migros-Genossenschafts-Bund, Zürich
# 1                     Freestar-Informatik AG, Zürich
# 2                           Sparrow Ventures, Zürich
# 3                               Biotronik AG, Bülach
# 4                               Biotronik AG, Bülach
# ...                                              ...
# 9718           Schweizer Radio und Fernsehen, Zürich
# 9719                             skyguide, Dübendorf
# 9720           Schweizer Radio und Fernsehen, Zürich
# 9721  Eidgenössische Finanzmarktaufsicht FINMA, Bern
# 9722             ELAN Personal AG, Luzern / Rotkreuz
#
# [9723 rows x 4 columns]

# %%
test = pd.read_csv(
    "/Users/jomaye/Documents/Programming/04-DS-repos/Python/email-scraper/job-urls.csv"
) 
test # check, if it worked?
# Out:
#                            Date  \
# 0     2023-01-04 06:16:14+00:00
# 1     2023-01-04 06:16:14+00:00
# 2     2023-01-04 06:16:14+00:00
# 3     2023-01-04 06:16:14+00:00
# 4     2023-01-04 06:16:14+00:00
# ...                         ...
# 9718  2021-11-01 07:04:45+00:00
# 9719  2021-11-01 07:04:45+00:00
# 9720  2021-11-01 07:04:45+00:00
# 9721  2021-11-01 07:04:45+00:00
# 9722  2021-11-01 07:04:45+00:00
#
#                                                     url  \
# 0     https://www.jobs.ch/de/stellenangebote/detail/...
# 1     https://www.jobs.ch/de/stellenangebote/detail/...
# 2     https://www.jobs.ch/de/stellenangebote/detail/...
# 3     https://www.jobs.ch/de/stellenangebote/detail/...
# 4     https://www.jobs.ch/de/stellenangebote/detail/...
# ...                                                 ...
# 9718  https://www.jobs.ch/de/stellenangebote/detail/...
# 9719  https://www.jobs.ch/de/stellenangebote/detail/...
# 9720  https://www.jobs.ch/de/stellenangebote/detail/...
# 9721  https://www.jobs.ch/de/stellenangebote/detail/...
# 9722  https://www.jobs.ch/de/stellenangebote/detail/...
#
#                                               Job Title  \
# 0     Data Scientist - Optimierung Filialperformance...
# 1              Praktikant/in Backoffice 100% [Ref:1785]
# 2     Salesforce Consulting Trainee at a leading Men...
# 3        Praktikum im Bereich Manufacturing Engineering
# 4     Internship in Sterilization and Contamination ...
# ...                                                 ...
# 9718  Praktikant:in Social Media und Community SRF News
# 9719  Initial Training Academy (ATCO) Instructor: AC...
# 9720  Praktikant:in Social Media und Community SRF News
# 9721  Aktuar oder Ökonom in der Versicherungsaufsich...
# 9722                                 Engineer/Scientist
#
#                                     Employer Company
# 0                Migros-Genossenschafts-Bund, Zürich
# 1                     Freestar-Informatik AG, Zürich
# 2                           Sparrow Ventures, Zürich
# 3                               Biotronik AG, Bülach
# 4                               Biotronik AG, Bülach
# ...                                              ...
# 9718           Schweizer Radio und Fernsehen, Zürich
# 9719                             skyguide, Dübendorf
# 9720           Schweizer Radio und Fernsehen, Zürich
# 9721  Eidgenössische Finanzmarktaufsicht FINMA, Bern
# 9722             ELAN Personal AG, Luzern / Rotkreuz
#
# [9723 rows x 4 columns]

# %% [markdown]
# ### 6) Close the Connection to the Email-Server

# %%
# close the connection and logout
imap.close()
imap.logout()
# Out:
# ('BYE', [b'Microsoft Exchange Server IMAP4 server signing off.'])

# %% [markdown]
# ### 7) Next Steps?
#
# - **Update your dataset**: Make an `update-data.py`-file, which will always attach the newest data to your ds every day.
# - **Create a UI**: You download the `.csv`-file with the newest data and populate an `.html`-file with `<a>`-tags that contain all these URLs.

# %% [markdown]
# ### 💭 Important Things to know about generating those Datasets! 🧐

# %% [markdown]
# #### <u>The Outputs from Crawling my Emails</u>:

# %%
for i in range(messages, messages-N, -1): # Why do we do this weird "backward"-loop? --> we want to iterate from the top to the bottom 
    # Key: in order to go "forward in time" (starting in the distant past), we need to iterate by typing in the 
    # following parameters: `messages-N, messages+1` and leave out "-1"(!!) at the end as the 3rd // last argument...
    # Backwards would be: `range(messages, messages-N, -1)`
    # fetch the email message by ID
    res, msg = imap.fetch(str(i), "(RFC822)") # `RFC822` is a special format that we can use to fetch the emails from the server: https://www.rfc-editor.org/rfc/rfc822
    for response in msg:
        if isinstance(response, tuple):
            msg = email.message_from_bytes(response[1]) # parse the bytes returned by the `fetch()`-method to a proper "Message"-object
            subject, encoding = decode_header(msg["Subject"])[0] # decode the "subject" of the email-address to human-readable Unicode.
            if isinstance(subject, bytes): # if the "subject" is from the data-type "bytes", decode to str
                subject = subject.decode(encoding)
            From, encoding = decode_header(msg.get("From"))[0] # decode email-sender (= "From") of the email-address to human-readable Unicode.
            if isinstance(From, bytes): # if the sender (= "From") is from the data-type "bytes", decode to str
                From = From.decode(encoding)
            print("Subject:", subject)
            print("From:", From)
            print(msg['Date'])
            todays_email_date = msg['Date']
            dates_array.append(todays_email_date) # append the dates to my empty array
            # if the email message is "multipart":  for instance, an email message can contain the "text/html"-content AND "text/plain"-parts, e.g. it has the HTML and(!) plain text versions of the message.
            if msg.is_multipart():
                # iterate over email parts
                for part in msg.walk():
                    # extract content type of email
                    content_type = part.get_content_type()
                    content_disposition = str(part.get("Content-Disposition"))
                    try:
                        # get the email body
                        body = part.get_payload(decode=True).decode()
                        lines = body.split('\n')
                        job_titles = []
                        companies = []
                        for line in lines:
                            if "https://www.jobs.ch/de/stellenangebote/detail/" in line:
                                job_titles.append(lines[lines.index(line) - 2])
                                companies.append(lines[lines.index(line) - 1])
                        matches_plural = re.findall(r".*neue Jobs.*", body)
                        matches_singular = re.findall(r".*neuer Job.*", body)
                        matches = matches_singular + matches_plural # concatenate the 2 lists into 1 (bigger) list
                        new_jobs_per_day = list(map(lambda string: int(string[0:2]), matches)) # take only the first element of each string (= which is the "number" - currently given as a `string` - that we are interested in, in order to calculate the total number of new open job position that opened "today")
                        total_new_jobs_today = sum(new_jobs_per_day)
                        urls = re.findall(r"https://www.jobs.ch/de/stellenangebote/detail/\S+", body)
                        currently_open_job_positions = len(urls)
                        total_jobs_available_today_array.append(currently_open_job_positions) 
                        new_jobs_today_array.append(total_new_jobs_today)
                        print(matches)
                        print(new_jobs_per_day)
                        print(currently_open_job_positions)
                        print(total_new_jobs_today)
                        print(urls)
                        urls_array.append(urls)
                        print(len(urls))
                        print(job_titles)
                        job_titles_array.append(job_titles)
                        print(len(job_titles))
                        print(companies)
                        companies_array.append(companies)
                        print(len(companies))
                        #print(body)
                        #print(matches_singular)
                        #print(matches_plural)
                    except:
                        pass
                    #if content_type == "text/plain" and "attachment" not in content_disposition:
                        # print text/plain emails and skip attachments
                        #print(body)
                    if "attachment" in content_disposition: # vorher: `elif` (statt `if`!)
                        # download attachment
                        filename = part.get_filename()
                        if filename:
                            folder_name = clean(subject)
                            if not os.path.isdir(folder_name):
                                # make a folder for this email (named after the subject)
                                os.mkdir(folder_name)
                            filepath = os.path.join(folder_name, filename)
                            # download attachment and save it
                            open(filepath, "wb").write(part.get_payload(decode=True))
            else:
                # extract content type of email
                content_type = msg.get_content_type()
                # get the email body
                body = msg.get_payload(decode=True).decode()
                #if content_type == "text/plain":
                    # print only text email parts
                    #print(body)
            #if content_type == "text/html":
                # if it's HTML, create a new HTML file and open it in browser
                #folder_name = clean(subject)
                #if not os.path.isdir(folder_name):
                    # make a folder for this email (named after the subject)
                    #os.mkdir(folder_name)
                #filename = "index.html"
                #filepath = os.path.join(folder_name, filename)
                # write the file
                #open(filepath, "w").write(body)
                # open in the default browser
                webbrowser.open(filepath)
            print("="*100)
dict_for_df['Date'] = dates_array
dict_for_df['Total of open Job-Positions up until today'] = total_jobs_available_today_array
dict_for_df['New Jobs published Today'] = new_jobs_today_array

### 2nd DF:
for (date, url, title, company) in zip(dates_array, urls_array,  job_titles_array, companies_array):
    dict_for_df2[date] = [url, title, company] # this will add new keys to the dictionary, where the 'dates' are the keys and a list (of sublists, containing the URLs, Job-Titles and Company-Names) as the values...
# Out:
# Subject: 59 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Wed, 4 Jan 2023 06:16:14 +0000
# ['7 neue Jobs für Data Scientist Jobs\r', '3 neue Jobs für Web Developer Jobs\r', '16 neue Jobs für Studentische Hilfskraft Jobs\r', '16 neue Jobs für Studentischer Mitarbeiter Jobs\r', '17 neue Jobs für Student Jobs\r']
# [7, 3, 16, 16, 17]
# 51
# 59
# ['https://www.jobs.ch/de/stellenangebote/detail/213d4319-f0a4-42ec-836b-5dc9417a48d4/?hash=5c9995cb43cf3073dcaf0fd3068564c9&profile-id=3e604a99-5577-4a68-b147-8522488c1e04&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2', 'https://www.jobs.ch/de/stellenangebote/detail/9f6dad5c-bcaa-498f-b3c9-78e9fe2afdc6/?hash=5c9995cb43cf3073dcaf0fd3068564c9&profile-id=3e604a99-5577-4a68-b147-8522488c1e04&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2', 'https://www.jobs.ch/de/stellenangebote/detail/2c35e147-3a1c-4311-bc48-7c0d2a7c4c6d/?hash=5c9995cb43cf3073dcaf0fd3068564c9&profile-id=3e604a99-5577-4a68-b147-8522488c1e04&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2', 'https://www.jobs.ch/de/stellenangebote/detail/1e931f75-beea-4db6-aef7-aa089eefceae/?hash=5c9995cb43cf3073dcaf0fd3068564c9&profile-id=3e604a99-5577-4a68-b147-8522488c1e04&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2', 'https://www.jobs.ch/de/stellenangebote/detail/2ed0e619-6d91-4459-92bf-9eb49f09d760/?hash=5c9995cb43cf3073dcaf0fd3068564c9&profile-id=3e604a99-5577-4a68-b147-8522488c1e04&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2', 'https://www.jobs.ch/de/stellenangebote/detail/78bbb49c-254b-4dd9-a7da-44489c4700d5/?hash=0a139e7b5856eb662fe9799d0cc966df&profile-id=102d7b51-24de-4b78-83bc-ee3626ec32dc&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2', 'https://www.jobs.ch/de/stellenangebote/detail/97e0809d-b122-4d7a-841c-439e473b7e48/?hash=0a139e7b5856eb662fe9799d0cc966df&profile-id=102d7b51-24de-4b78-83bc-ee3626ec32dc&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2', 'https://www.jobs.ch/de/stellenangebote/detail/5d776aa8-c7b1-47cd-9843-5d132d97b4be/?hash=fbe73fe5ed397c42918bfc75508d3b07&profile-id=02ce1cf1-efd1-4e40-ad52-3e8447c1fe2d&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2', 'https://www.jobs.ch/de/stellenangebote/detail/70b49f82-afbb-41de-8722-9a373291dd5f/?hash=fbe73fe5ed397c42918bfc75508d3b07&profile-id=02ce1cf1-efd1-4e4 ...
# 51
# ['Data Scientist - Optimierung Filialperformance (w/m/d)\r', 'Senior Manager – Lighthouse Data Science\r', 'Scientist in Cell Line Development\r', 'Pharmabranche: Einstieg in die Software-Entwicklung\r', 'Postdoctoral researcher in management and control of dynamic capacity in shared mobility networks\r', 'Web-Entwickler (m/w/d)\r', 'Algorithmenentwickler für IoT-Produkte\r', 'Praktikum (w/m/d), 100% in Schaffhausen ab August 2023\r', 'Salesforce Consulting Trainee at a leading Mental Health Startup\r', 'Praktikum im Bereich Manufacturing Engineering\r', 'Internship in Sterilization and Contamination Control (m/w/d)\r', 'Praktikant/in Projekt- & Qualitätsmanagement\r', 'Praktikant Junior Informatiker (m/w) 100% [Ref:2169/1]\r', 'Schnupperlehre als Netzelektriker:in EFZ, Fachrichtung Energie\r', 'Praktikant/in Backoffice 100% [Ref:1785]\r', 'Schnupperlehre als Gebäudereiniger:in EFZ\r', 'Praktikant:in Pflege 80-100% Same Day Surgery\r', 'Praktikum (w/m/d), 100% in Schaffhausen ab August 2023\r', 'Salesforce Consulting Trainee at a leading Mental Health Startup\r', 'Praktikum im Bereich Manufacturing Engineering\r', 'Internship in Sterilization and Contamination Control (m/w/d)\r', 'Praktikant/in Projekt- & Qualitätsmanagement\r', 'Praktikant Junior Informatiker (m/w) 100% [Ref:2169/1]\r', 'Schnupperlehre als Netzelektriker:in EFZ, Fachrichtung Energie\r', 'Schnupperlehre als Gebäudereiniger:in EFZ\r', 'Praktikant:in Pflege 80-100% Same Day Surgery\r', 'Praktikant/in Backoffice 100% [Ref:1785]\r', 'Praktikum (w/m/d), 100% in Schaffhausen ab August 2023\r', 'Salesforce Consulting Trainee at a leading Mental Health Startup\r', 'Praktikum im Bereich Manufacturing Engineering\r', 'Internship in Sterilization and Contamination Control (m/w/d)\r', 'Praktikant/in Projekt- & Qualitätsmanagement\r', 'Praktikant Junior Informatiker (m/w) 100% [Ref:2169/1]\r', 'Schnupperlehre als Netzelektriker:in EFZ, Fachrichtung Energie\r', 'Praktikant/in Backoffice 100% [Ref:1785]\r', 'Schnupperlehre als Gebäudereiniger:in EFZ\r', 'Praktikant:in Pflege 80-100% Same Day Surgery\r', 'Ökonomen oder Juristen betreffend stationäre Tarife 80-100% (m/w)\r', 'Full Stack PHP Developer (80-100%) (m/w)\r', 'Data Analyst:in Unterhaltung\r', 'Praktikum/Abschlussarbeit IoT Solution Engineer\r', 'Juristische Praktikantin/Juristischen Praktikanten\r', 'Hochschulpraktikant*in Produktmanagement Elektromobilität\r', 'Manager - FS Regulatory & Compliance – Fraud Prevention\r', 'Senior Front-End Developer\r', 'Senior Java Full-Stack & Spark Developer\r', 'Praktikant*in Administration\r', 'Praktikum als kaufmännische Assistenz (a)\r', 'Praktikant:in Studienmanagement\r', 'IT solution engineer for personalized health research (f/m)\r', 'Trainee-Programm – Unabhängige Vermögensberatung, 60-100%\r']
# 51
# ['Migros-Genossenschafts-Bund, Zürich\r', 'KPMG, Zurich\r', 'Global IT-GITR, Deutschschweiz, Stadt Zürich / Zürichsee\r', 'ProPharma Systems AG, Wettingen AG\r', 'ETH Zürich, Zurich\r', 'Sensirion AG, Stäfa\r', 'Sensirion AG, Stäfa, Schweiz\r', 'Concordia, Schaffhausen\r', 'Sparrow Ventures, Zürich\r', 'Biotronik AG, Bülach\r', 'Biotronik AG, Bülach\r', 'Kantonale Verwaltung Zürich, Zürich Altstetten\r', 'Freestar-Informatik AG, Raum Zürich\r', 'Flughafen Zürich AG, Zürich-Flughafen\r', 'Freestar-Informatik AG, Zürich\r', 'Flughafen Zürich AG, Zürich-Flughafen\r', 'Universitätsspital Zürich, Zürich\r', 'Concordia, Schaffhausen\r', 'Sparrow Ventures, Zürich\r', 'Biotronik AG, Bülach\r', 'Biotronik AG, Bülach\r', 'Kantonale Verwaltung Zürich, Zürich Altstetten\r', 'Freestar-Informatik AG, Raum Zürich\r', 'Flughafen Zürich AG, Zürich-Flughafen\r', 'Flughafen Zürich AG, Zürich-Flughafen\r', 'Universitätsspital Zürich, Zürich\r', 'Freestar-Informatik AG, Zürich\r', 'Concordia, Schaffhausen\r', 'Sparrow Ventures, Zürich\r', 'Biotronik AG, Bülach\r', 'Biotronik AG, Bülach\r', 'Kantonale Verwaltung Zürich, Zürich Altstetten\r', 'Freestar-Informatik AG, Raum Zürich\r', 'Flughafen Zürich AG, Zürich-Flughafen\r', 'Freestar-Informatik AG, Zürich\r', 'Flughafen Zürich AG, Zürich-Flughafen\r', 'Universitätsspital Zürich, Zürich\r', 'tarifsuisse ag, Zürich\r', 'Threema GmbH, 8808 Pfäffikon SZ (Grossraum Zürich)\r', 'Schweizer Radio und Fernsehen, Zürich\r', 'Syntegon, Beringen\r', 'Stadt Schaffhausen, Schaffhausen\r', 'EWZ, Zürich\r', 'KPMG, Zurich\r', 'Vontobel, Zürich\r', 'Synechron Switzerland, Zürich\r', 'Stadt Zürich Gesundheitszentren für das Alter, Zürich\r', 'Art of Work Personalberatung AG, Winterthur\r', 'HSO Wirtschaftsschule Schweiz AG, Zürich\r', 'ETH Zürich, Zurich\r', 'VZ VermögensZentrum AG, Affoltern am Albis\r']
# 51
# ====================================================================================================
# Subject: 8 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Tue, 3 Jan 2023 05:51:23 +0000
# ['1 neuer Job für Web Designer Jobs\r', '1 neuer Job für Web Developer Jobs\r', '2 neue Jobs für Studentische Hilfskraft Jobs\r', '2 neue Jobs für Studentischer Mitarbeiter Jobs\r', '2 neue Jobs für Student Jobs\r']
# [1, 1, 2, 2, 2]
# 22
# 8
# ['https://www.jobs.ch/de/stellenangebote/detail/9783914c-4902-46f2-a21d-39ddc32dddac/?hash=9286de61645a460ef4466fa3a4ade8c0&profile-id=b34273f5-c5cc-4ce7-b5cf-882c66c7c54c&reference-date=2023-01-01&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d', 'https://www.jobs.ch/de/stellenangebote/detail/9783914c-4902-46f2-a21d-39ddc32dddac/?hash=0a139e7b5856eb662fe9799d0cc966df&profile-id=102d7b51-24de-4b78-83bc-ee3626ec32dc&reference-date=2023-01-01&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d', 'https://www.jobs.ch/de/stellenangebote/detail/864a2b09-9a17-46ac-bef9-3e9b346d6a21/?hash=fbe73fe5ed397c42918bfc75508d3b07&profile-id=02ce1cf1-efd1-4e40-ad52-3e8447c1fe2d&reference-date=2023-01-01&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d', 'https://www.jobs.ch/de/stellenangebote/detail/9ecf15b0-3c7f-45c4-970a-25b0bf2c5a8c/?hash=fbe73fe5ed397c42918bfc75508d3b07&profile-id=02ce1cf1-efd1-4e40-ad52-3e8447c1fe2d&reference-date=2023-01-01&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d', 'https://www.jobs.ch/de/stellenangebote/detail/864a2b09-9a17-46ac-bef9-3e9b346d6a21/?hash=b9eb68d765f0c7e76d531f542e05302e&profile-id=c886c8e3-8247-4612-944b-15df77d6d964&reference-date=2023-01-01&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d', 'https://www.jobs.ch/de/stellenangebote/detail/9ecf15b0-3c7f-45c4-970a-25b0bf2c5a8c/?hash=b9eb68d765f0c7e76d531f542e05302e&profile-id=c886c8e3-8247-4612-944b-15df77d6d964&reference-date=2023-01-01&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d', 'https://www.jobs.ch/de/stellenangebote/detail/864a2b09-9a17-46ac-bef9-3e9b346d6a21/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-01&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d', 'https://www.jobs.ch/de/stellenangebote/detail/9ecf15b0-3c7f-45c4-970a-25b0bf2c5a8c/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-01&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d', 'https://www.jobs.ch/de/stellenangebote/detail/ca31f2ca-cdbf-4f21-bc1a-9912ed13106a/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medi ...
# 22
# ['Full Stack Developer React / Next.js at a leading Mental Health Startup\r', 'Full Stack Developer React / Next.js at a leading Mental Health Startup\r', 'Student:in Service\r', 'Praktikant*in Datenmanagement 30-50%\r', 'Student:in Service\r', 'Praktikant*in Datenmanagement 30-50%\r', 'Student:in Service\r', 'Praktikant*in Datenmanagement 30-50%\r', 'Web Developer (React and/or React Native) (f/m/d) 100%\r', 'Senior Data Analyst - B2B (w/m/d) 100%\r', 'Praktikant «Landbote» (m/w/d) 100%\r', 'Senior Economist\r', 'Praktikant Digital/Online - Marketing (m/w/d)\r', 'Praktikant/-in Altlasten\r', 'UX/UI Designer (w/m/d) 100%\r', 'Senior Java Developer in the field of Marketing Technology, Focus BSI Customer Suite\r', '(Senior) Data scientist - AI & Machine Learning (f/m/d) 100%\r', 'Studierende/r HF/FH\r', 'Ökonom / Datenanalyst (w/m/d)\r', 'Praktikant*in Administration\r', 'Advanced Conversion Rate Optimization (CRO) Manager (f/m/d) 100%\r', 'l Python Backend Developer (incl. AWS/GCS Engineering) (f/m/d) 100%\r']
# 22
?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45a ...
# 25
# ['Head of UI Design (m/w/d)\r', 'Junior Java Developer (m/w/d)\r', 'Legal Trainee (temporary)\r', 'Social-Media-Praktikant:in mit Schwerpunkt Video (m/w/d)\r', 'Junior Consultant – Unabhängige Vermögensberatung, 60-100%\r', 'Legal Trainee (temporary)\r', 'Social-Media-Praktikant:in mit Schwerpunkt Video (m/w/d)\r', 'Junior Consultant – Unabhängige Vermögensberatung, 60-100%\r', 'Legal Trainee (temporary)\r', 'Social-Media-Praktikant:in mit Schwerpunkt Video (m/w/d)\r', 'Junior Consultant – Unabhängige Vermögensberatung, 60-100%\r', 'Praktikum Musikredaktion.\r', 'Head of UX Design (m/f/d) 80-100 %\r', 'Trainee Asset Management Real Estate Direct (w/m/d)\r', 'E-Banking Web-Applikationsentwickler:in\r', 'Werkstudent:in Digital Business Ringier Advertising 50-100%\r', 'Data Analytics Projektleiter (m/w/d), 80% bis 100%, Zürich\r', 'Web3 Praktikum.\r', 'Full-Stack Web Developer / Team Lead (m/w/d)\r', 'Intern Venture Capital (100%, 6 Months)\r', 'Senior Data Scientist (80-100%)\r', 'Job étudiant à temps partiel, 20-100%\r', 'Dissertant*in 80-100% Klinik für Thoraxchirurgie\r', 'Senior E-Banking Web-Applikationsentwickler:in\r', 'Praktikant:in Social Media RED\r']
# 25
# ['ROCKEN, Kloten\r', 'ROCKEN, Spreitenbach\r', 'Kessler.Vogler Gmbh, Zürich\r', 'ETH Zürich, Zürich\r', 'VZ VermögensZentrum AG, Meilen\r', 'Kessler.Vogler Gmbh, Zürich\r', 'ETH Zürich, Zürich\r', 'VZ VermögensZentrum AG, Meilen\r', 'Kessler.Vogler Gmbh, Zürich\r', 'ETH Zürich, Zürich\r', 'VZ VermögensZentrum AG, Meilen\r', 'Energy Schweiz AG, Zürich\r', 'JobCloud AG, Zürich\r', 'Swiss Finance & Property Group, Zürich\r', 'Liechtensteinische Landesbank AG, Eschen / Zürich\r', 'Ringier Advertising, Zürich-Altstetten\r', 'DataVision AG, Zürich\r', 'Energy Schweiz AG, Zürich\r', 'BERTA Kommunikation AG, Zürich\r', 'Sparrow Ventures, Zürich\r', 'Cembra Money Bank, Zürich\r', 'VZ VermögensZentrum AG, Zürich\r', 'Universitätsspital Zürich, Zürich\r', 'Liechtensteinische Landesbank AG, Eschen / Zürich\r', 'Ringier Sports, Zürich\r']
# 25
# ====================================================================================================
# Subject: 40 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Sat, 31 Dec 2022 05:57:44 +0000
# ['3 neue Jobs für Data Scientist Jobs\r', '4 neue Jobs für Web Developer Jobs\r', '11 neue Jobs für Studentische Hilfskraft Jobs\r', '11 neue Jobs für Studentischer Mitarbeiter Jobs\r', '11 neue Jobs für Student Jobs\r']
# [3, 4, 11, 11, 11]
# 40
# 40
# ['https://www.jobs.ch/de/stellenangebote/detail/b85761c6-81a5-4c5d-84c4-63a235b61c17/?hash=5c9995cb43cf3073dcaf0fd3068564c9&profile-id=3e604a99-5577-4a68-b147-8522488c1e04&reference-date=2022-12-29&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=5830ce0d-0253-414b-85d7-d68100b0b815', 'https://www.jobs.ch/de/stellenangebote/detail/e3ee7c81-7611-48d0-b297-ea4824c8dffe/?hash=5c9995cb43cf3073dcaf0fd3068564c9&profile-id=3e604a99-5577-4a68-b147-8522488c1e04&reference-date=2022-12-29&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid
ischer Modellierung\r', 'HMS-Praktikant/in Betriebliche Bildung 01.08.2023 - 31.07.2024 100%\r', 'HMS-Praktikant/in Personal Schulen und Mittelschulen 01.08.2023 - 31.07.2024 100%\r', 'Hoch-/Fachhochschul-praktikant/in Extension Ackerbau\r', 'SACHBEARBEITER:IN FINANZBUCHHALTUNG – ALLROUNDLER:IN (100%)\r', 'Praktikant:in News\r', 'Praktikant im Datenmanagement Infrastruktur (w/m)\r', 'Praktikum/Trainee HR & Recruiting 60-100% (Uni/FH/HF)\r', 'Postdoc in Microbiome Biology and Soil Microbial Ecology\r', 'Senior Full-Stack Software Developer\r', 'Senior Web-Entwickler:in\r', 'Hochschulpraktikum Business Analyse Produktentwicklung (m/w)\r', 'Trainee PR/ Communications / Events (6 - 12 Monate)\r', 'R&D Praktikant/in Thermische Verfahrenstechnik\r', 'Praktikant/in Verkehrsplanung (60 - 90 %)\r', 'Java Fullstack Entwickler (m/w/d) - Fullstack Developer (80-100%)\r', 'Praktikant:in Wirtschaftsjournalismus\r', 'Praktikant:in Sponsoring & Events - befristet\r', 'Praktikant/in im Bereich Küche, (80 - 100 %), 6 - 12 Monate befristet, Alterszentrum Adlergarten\r']
# 40
# ['Credit Suisse AG, Zürich\r', 'LGT, Zürich\r', 'Credit Suisse AG, Zürich\r', 'LGT, Zürich\r', 'Credit Suisse AG, Zürich\r', 'Kantonspolizei Zürich, Zürich\r', 'Kantonale Verwaltung Zürich, Zürich\r', 'Bundesamt für Meteorologie und Klimatologie MeteoSchweiz, Zürich-Flughafen\r', 'Kantonale Verwaltung Zürich, Zürich\r', 'Kantonale Verwaltung Zürich, Zürich\r', 'Agroscope, Zürich\r', 'gebana AG, Zürich\r', 'Bundesamt für Meteorologie und Klimatologie MeteoSchweiz, Zürich-Flughafen\r', 'Kantonale Verwaltung Zürich, Zürich\r', 'Kantonale Verwaltung Zürich, Zürich\r', 'Kantonspolizei Zürich, Zürich\r', 'Kantonale Verwaltung Zürich, Zürich\r', 'Agroscope, Zürich\r', 'gebana AG, Zürich\r', 'Kantonale Verwaltung Zürich, Zürich\r', 'Kantonspolizei Zürich, Zürich\r', 'Bundesamt für Meteorologie und Klimatologie MeteoSchweiz, Zürich-Flughafen\r', 'Kantonale Verwaltung Zürich, Zürich\r', 'Kantonale Verwaltung Zürich, Zürich\r', 'Agroscope, Zürich\r', 'gebana AG, Zürich\r', 'Blick-Gruppe, Zürich-Seefeld\r', 'Schweizerische Südostbahn AG, Samstagern\r', 'yellowshark® AG, Zürich\r', 'Agroscope, Zürich-Affoltern ZH\r', 'FE fundinfo, Zürich\r', 'Glutz AG, Wallisellen\r', 'Assura, Zürich\r', 'Renault Suisse SA, Urdorf\r', 'Maerz Ofenbau AG, Zürich\r', 'Stadt Winterthur, Winterthur\r', 'Ratbacher AG, Bern\r', 'Blick-Gruppe, Zürich-Seefeld\r', 'Ochsner Sport AG, Dietikon (Zürich)\r', 'Stadt Winterthur, Winterthur\r']
# 40
# ====================================================================================================
# Subject: 34 neue Stellenangebote gefunden
# From: "jobs.ch Job-Alarm" <jobmail@jobs.ch>
# Wed, 28 Dec 2022 06:10:27 +0000
# ['3 neue Jobs für Data Scientist Jobs\r', '2 neue Jobs für Web Developer Jobs\r', '9 neue Jobs für Studentische Hilfskraft Jobs\r', '9 neue Jobs für Studentischer Mitarbeiter Jobs\r', '11 neue Jobs für Student Jobs\r']
# [3, 2, 9, 9, 11]
# 46
# 34
# ['https://www.jobs.ch/de/stellenangebote/detail/b7ec4f52-8a02-4568-a56a-4528c91937c8/?hash=5c9995cb43cf3073dcaf0fd3068564c9&profile-id=3e604a99-5577-4a68-b147-8522488c1e04&reference-date=2022-12-26&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=f5c63bef-f1fd-40e4-b1fa-b43e3fc6be97', 'https://www.jobs.ch/de/stellenangebote/detail/7fdca72a-fa3f-4016-91ad-927629a478d2/?hash=5c9995cb43cf3073dcaf0fd3068564c9&profile-id=3e604a99-5577-4a68-b147-8522488c1e04&reference-date=2022-12-26&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=f5c63bef-f1fd-40e4-b1fa-b43e3fc6be97', 'https://www.jobs.ch/de/stellenangebote/detail/8728d705-2a59-4c94-86af-80f45029a81a/?hash=5c9995cb43cf3073dcaf0fd3068564c9&profile-id=3e604a99-5577-4a68-b147-8522488c1e04&reference-date=2022-12-26&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=f5c63bef-f1fd-40e4-b1fa-b43e3fc6be97', 'https://www.jobs.ch/de/stellenangebote/detail/eaec9680-8e33-455f-bc77-57c604aca939/?hash=0a139e7b5856eb662fe9799d0cc966df&profile-id=102d7b51-24de-4b78-83bc-ee3626ec32dc&reference-date=2022-12-26&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=f5c63bef-f1fd-40e4-b1fa-b43e3fc6be97', 'https://www.jobs.ch/de/stellenangebote/detail/fdc2b42c-8231-4fa8-84f9-317993bbc69f/?hash=fbe73fe5ed397c42918bfc75508d3b07&profile-id=02ce1cf1-efd1-4e40-ad52-3e8447c1fe2d&reference-date=2022-12-26&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=f5c63bef-f1fd-40e4-b1fa-b43e3fc6be97', 'https://www.jobs.ch/de/stellenangebote/detail/2c0149ce-0237-4480-bd46-40dcc3c36d83/?hash=fbe73fe5ed397c42918bfc75508d3b07&profile-id=02ce1cf1-efd1-4e40-ad52-3e8447c1fe2d&reference-date=2022-12-26&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=f5c63bef-f1fd-40e4-b1fa-b43e3fc6be97', 'https://www.jobs.ch/de/stellenangebote/detail/04c9d891-61ba-4555-b4d4-299a1752669f/?hash=fbe73fe5ed397c42918bfc75508d3b07&profile-id=02ce1cf1-efd1-4e40-ad52-3e8447c1fe2d&reference-date=2022-12-26&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=f5c63bef-f1fd-40e4-b1fa-b43e3fc6be97', 'https://www.jobs.ch/de/stellenangebote/detail/634090ee-ffd2-4cf6-81fa-47cfcf6f8398/?hash=fbe73fe5ed397c42918bfc75508d3b07&profile-id=02ce1cf1-efd1-4e40-ad52-3e8447c1fe2d&reference-date=2022-12-26&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=f5c63bef-f1fd-40e4-b1fa-b43e3fc6be97', 'https://www.jobs.ch/de/stellenangebote/detail/73d9d062-d2a6-478e-929d-c910bb843795/?hash=fbe73fe5ed397c42918bfc75508d3b07&profile-id=02ce1cf1-efd1-4e4 ...
# 46
# ['(Senior) Data Scientist Online Shop\r', 'Stammdatenspezialist*in\r', 'Pharmabranche: Einstieg in die Software-Entwicklung\r', 'Senior C# / .NET Developer\r', 'Praktikant*in Nachhaltigkeit\r', 'Praktikant*in Content Creation\r', 'Praktikant*in Medienstelle & Community Management\r', 'Praktikant*in Social Media\r', 'PWA - Praktikant:in 100 %\r', 'Praktikum Diversity & Inclusion (40-60%)\r', 'ACCOUNTING TRAINEE 60-80% (M/W/D)\r', 'Praktikant/in Buchhaltung & Controlling 40-60%\r', 'Assistent/in Personal (befristet für 1 Jahr 50%)\r', 'Praktikant*in Social Media\r', 'Praktikant*in Medienstelle & Community Management\r', 'Praktikant*in Nachhaltigkeit\r', 'Praktikant*in Content Creation\r', 'Praktikum Diversity & Inclusion (40-60%)\r', 'PWA - Praktikant:in 100 %\r', 'ACCOUNTING TRAINEE 60-80% (M/W/D)\r', 'Praktikant/in Buchhaltung & Controlling 40-60%\r', 'Assistent/in Personal (befristet für 1 Jahr 50%)\r', 'Praktikant*in Medienstelle & Community Management\r', 'Praktikant*in Social Media\r', 'Praktikant*in Nachhaltigkeit\r', 'Praktikant*in Content Creation\r', 'Praktikum Diversity & Inclusion (40-60%)\r', 'PWA - Praktikant:in 100 %\r', 'ACCOUNTING TRAINEE 60-80% (M/W/D)\r', 'Praktikant/in Buchhaltung & Controlling 40-60%\r', 'Oberärztin / Oberarzt Nephrologie 80-100%\r', 'Assistent/in Personal (befristet für 1 Jahr 50%)\r', 'Internship Business Development\r', 'Praktikum Marketing und Kommunikation (w/m/d)\r', 'Praktikum Musikredaktion.\r', 'Master Data Specialist (m,w,d) 100%\r', 'Head of UX Design (m/f/d) 80-100 %\r', 'Ökonomen oder Juristen betreffend stationäre Tarife 80-100% (m/w)\r', 'Praktikant:in Product Management RED\r', 'Praktikant:in Sportredaktion / Content Creation\r', 'Senior Data Scientist (80-100%)\r', 'Grafik Designer mit Coding und Motion Skills\r', 'Web3 Praktikum.\r', 'Praktikant Supply Management (m/w)\r', 'Praktikum Praxisintegriertes Bachelor-Studium (PiBS) in Informatik (w/m/d)\r', 'Werkstudent:in Digital Business Ringier Advertising 50-100%\r']
# 46
# ['Digitec, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'ProPharma Systems AG, Wettingen AG\r', 'Vontobel, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'ZHAW, Winterthur\r', 'WSL, Birmensdorf\r', 'IVECO (Schweiz) AG, Kloten / Zürich\r', 'Kunsthaus Zürich, Zürich\r', 'Kunsthaus Zürich, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'WSL, Birmensdorf\r', 'ZHAW, Winterthur\r', 'IVECO (Schweiz) AG, Kloten / Zürich\r', 'Kunsthaus Zürich, Zürich\r', 'Kunsthaus Zürich, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'Migros-Genossenschafts-Bund, Zürich\r', 'WSL, Birmensdorf\r', 'ZHAW, Winterthur\r', 'IVECO (Schweiz) AG, Kloten / Zürich\r', 'Kunsthaus Zürich, Zürich\r', 'Universitätsspital Zürich, Zürich\r', 'Kunsthaus Zürich, Zürich\r', 'Givaudan, Kemptthal\r', 'Feller AG, Horgen\r', 'Energy Schweiz AG, Zürich\r', 'ASSA ABLOY (Schweiz) AG, Richterswil\r', 'JobCloud AG, Zürich\r', 'tarifsuisse ag, Zürich\r', 'Ringier Sports, Zürich\r', 'Ringier Sports, Zürich\r', 'Cembra Money Bank, Zürich\r', 'Digitec, Zürich\r', 'Energy Schweiz AG, Zürich\r', 'Sodexo (Suisse) SA, Glattbrugg\r', 'Swiss Life AG, Zürich\r', 'Ringier Advertising, Zürich-Altstetten\r']
?hash=b9eb68d765f0c7e76d531f542e05302e&profile-id=c886c8e3-8247-4612-944b-15df77d6d964&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/5d776aa8-c7b1-47cd-9843-5d132d97b4be/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/70b49f82-afbb-41de-8722-9a373291dd5f/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/2e0da80e-5917-4d49-91af-950318e9199b/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/a5e526ff-6e27-41da-88ea-f43ba6020b78/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/b02fa303-8799-4f18-bff4-f4c3190d9c33/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/94a9e029-ebe3-4d4f-b00a-2c95022d861d/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/ea4b5146-fb29-462c-94b0-05e72b74ec69/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/7aaf07a9-b412-4f9d-8408-d4a27c740e5e/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/ab8b430c-bd41-4eea-a365-60fc3ac624e2/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/8295ccde-fef1-4d89-bd6f-f94bbfefa25a/?hash=6aba5feb1cb4599ab6c37d9dc49808c8&profile-id=77e09f9e-eff8-45ad-9607-3410c2dd2404&reference-date=2023-01-02&source=job_alert_email_direct&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/8209a80b-3ef4-42a3-91e4-779e14143b75/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/87210673-0ba2-4051-9821-91603a9bc7a1/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/35bae6c5-ccfe-46ae-9384-193b6efdc1b5/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/3e9ecc9f-a96b-457a-baf9-582c342d32fb/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/6c21da80-4a19-4381-9b56-93d2cdb8fbaf/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/ebff517c-436d-421f-888a-79d24a49f3a0/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/5f7019d9-9d33-4d1c-8318-d710f77f1176/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/1176e8a5-4a2b-4cd0-b7ca-55e0a916b2d6/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/daa71835-511d-40fc-8a64-8eafa5143045/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/14c091dc-4553-4aea-842c-4030b7147aba/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/c212deeb-fa04-4be8-aeee-bd54337ea618/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/36282b7f-cd9f-4c92-8fdd-6aaee5066999/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/8204d1bc-22e4-4030-a8fa-391d40c465a6/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2',
#    'https://www.jobs.ch/de/stellenangebote/detail/d0ce025f-dc7f-4578-bd5d-cbd7800d7b83/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=58a95130-2750-462f-9375-b6edc0abfac2'],
#   ['Data Scientist - Optimierung Filialperformance (w/m/d)\r',
#    'Senior Manager – Lighthouse Data Science\r',
#    'Scientist in Cell Line Development\r',
#    'Pharmabranche: Einstieg in die Software-Entwicklung\r',
#    'Postdoctoral researcher in management and control of dynamic capacity in shared mobility networks\r',
#    'Web-Entwickler (m/w/d)\r',
#    'Algorithmenentwickler für IoT-Produkte\r',
#    'Praktikum (w/m/d), 100% in Schaffhausen ab August 2023\r',
#    'Salesforce Consulting Trainee at a leading Mental Health Startup\r',
#    'Praktikum im Bereich Manufacturing Engineering\r',
#    'Internship in Sterilization and Contamination Control (m/w/d)\r',
#    'Praktikant/in Projekt- & Qualitätsmanagement\r',
#    'Praktikant Junior Informatiker (m/w) 100% [Ref:2169/1]\r',
#    'Schnupperlehre als Netzelektriker:in EFZ, Fachrichtung Energie\r',
#    'Praktikant/in Backoffice 100% [Ref:1785]\r',
#    'Schnupperlehre als Gebäudereiniger:in EFZ\r',
#    'Praktikant:in Pflege 80-100% Same Day Surgery\r',
#    'Praktikum (w/m/d), 100% in Schaffhausen ab August 2023\r',
#    'Salesforce Consulting Trainee at a leading Mental Health Startup\r',
#    'Praktikum im Bereich Manufacturing Engineering\r',
#    'Internship in Sterilization and Contamination Control (m/w/d)\r',
#    'Praktikant/in Projekt- & Qualitätsmanagement\r',
#    'Praktikant Junior Informatiker (m/w) 100% [Ref:2169/1]\r',
#    'Schnupperlehre als Netzelektriker:in EFZ, Fachrichtung Energie\r',
#    'Schnupperlehre als Gebäudereiniger:in EFZ\r',
#    'Praktikant:in Pflege 80-100% Same Day Surgery\r',
#    'Praktikant/in Backoffice 100% [Ref:1785]\r',
#    'Praktikum (w/m/d), 100% in Schaffhausen ab August 2023\r',
#    'Salesforce Consulting Trainee at a leading Mental Health Startup\r',
#    'Praktikum im Bereich Manufacturing Engineering\r',
#    'Internship in Sterilization and Contamination Control (m/w/d)\r',
#    'Praktikant/in Projekt- & Qualitätsmanagement\r',
#    'Praktikant Junior Informatiker (m/w) 100% [Ref:2169/1]\r',
#    'Schnupperlehre als Netzelektriker:in EFZ, Fachrichtung Energie\r',
#    'Praktikant/in Backoffice 100% [Ref:1785]\r',
#    'Schnupperlehre als Gebäudereiniger:in EFZ\r',
#    'Praktikant:in Pflege 80-100% Same Day Surgery\r',
#    'Ökonomen oder Juristen betreffend stationäre Tarife 80-100% (m/w)\r',
#    'Full Stack PHP Developer (80-100%) (m/w)\r',
#    'Data Analyst:in Unterhaltung\r',
#    'Praktikum/Abschlussarbeit IoT Solution Engineer\r',
#    'Juristische Praktikantin/Juristischen Praktikanten\r',
#    'Hochschulpraktikant*in Produktmanagement Elektromobilität\r',
#    'Manager - FS Regulatory & Compliance – Fraud Prevention\r',
#    'Senior Front-End Developer\r',
#    'Senior Java Full-Stack & Spark Developer\r',
#    'Praktikant*in Administration\r',
#    'Praktikum als kaufmännische Assistenz (a)\r',
#    'Praktikant:in Studienmanagement\r',
#    'IT solution engineer for personalized health research (f/m)\r',
#    'Trainee-Programm – Unabhängige Vermögensberatung, 60-100%\r'],
#   ['Migros-Genossenschafts-Bund, Zürich\r',
#    'KPMG, Zurich\r',
#    'Global IT-GITR, Deutschschweiz, Stadt Zürich / Zürichsee\r',
#    'ProPharma Systems AG, Wettingen AG\r',
#    'ETH Zürich, Zurich\r',
#    'Sensirion AG, Stäfa\r',
#    'Sensirion AG, Stäfa, Schweiz\r',
#    'Concordia, Schaffhausen\r',
#    'Sparrow Ventures, Zürich\r',
#    'Biotronik AG, Bülach\r',
#    'Biotronik AG, Bülach\r',
#    'Kantonale Verwaltung Zürich, Zürich Altstetten\r',
#    'Freestar-Informatik AG, Raum Zürich\r',
#    'Flughafen Zürich AG, Zürich-Flughafen\r',
#    'Freestar-Informatik AG, Zürich\r',
#    'Flughafen Zürich AG, Zürich-Flughafen\r',
#    'Universitätsspital Zürich, Zürich\r',
#    'Concordia, Schaffhausen\r',
#    'Sparrow Ventures, Zürich\r',
#    'Biotronik AG, Bülach\r',
#    'Biotronik AG, Bülach\r',
#    'Kantonale Verwaltung Zürich, Zürich Altstetten\r',
#    'Freestar-Informatik AG, Raum Zürich\r',
#    'Flughafen Zürich AG, Zürich-Flughafen\r',
#    'Flughafen Zürich AG, Zürich-Flughafen\r',
#    'Universitätsspital Zürich, Zürich\r',
#    'Freestar-Informatik AG, Zürich\r',
#    'Concordia, Schaffhausen\r',
#    'Sparrow Ventures, Zürich\r',
#    'Biotronik AG, Bülach\r',
?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d',
#    'https://www.jobs.ch/de/stellenangebote/detail/15b345b6-a451-488b-9485-c20717ed467d/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d',
#    'https://www.jobs.ch/de/stellenangebote/detail/9b320549-ad12-4a0c-ac49-f74bdadf3f49/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d',
#    'https://www.jobs.ch/de/stellenangebote/detail/4c314f72-76d3-4e3a-b5f0-86b6c7968324/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d',
#    'https://www.jobs.ch/de/stellenangebote/detail/bdbc0a02-9abf-4784-a6cf-62ab203a13a9/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d',
#    'https://www.jobs.ch/de/stellenangebote/detail/2009f80a-e6de-4efc-b676-96de6c4d3013/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d',
#    'https://www.jobs.ch/de/stellenangebote/detail/c9e43304-6dd8-474b-bb87-dc5750ebec35/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d',
#    'https://www.jobs.ch/de/stellenangebote/detail/ebea44e5-f967-485f-86d7-7bc323591b37/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d',
#    'https://www.jobs.ch/de/stellenangebote/detail/accf6c52-72d8-44b9-9873-b39967e4ab6d/?source=job_alert_promo&pid=1&utm_source=automail-job-push&utm_medium=email&utm_campaign=wb%3Ajobs%7Ctg%3Ab2c%7Ccn%3Aww%7Clg%3Ade%7Cmg%3Ajob-views%7Cpd%3An%7Ccd%3Ajob-alert&utm_content=job-link-promo&uid=6c67e29e-faf0-4238-ad1d-0e2a6c78868c&mid=d09494f6-b8f5-4c5f-8917-81bb0f39ec8d'],
#   ['Full Stack Developer React / Next.js at a leading Mental Health Startup\r',
#    'Full Stack Developer React / Next.js at a leading Mental Health Startup\r',
#    'Student:in Service\r',
#    'Praktikant*in Datenmanagement 30-50%\r',
#    'Student:in Service\r',
#    'Praktikant*in Datenmanagement 30-50%\r',
#    'Student:in Service\r',
#    'Praktikant*in Datenmanagement 30-50%\r',
#    'Web Developer (React and/or React Native) (f/m/d) 100%\r',
#    'Senior Data Analyst - B2B (w/m/d) 100%\r',
#    'Praktikant «Landbote» (m/w/d) 100%\r',
#    'Senior Economist\r',
#    'Praktikant Digital/Online - Marketing (m/w/d)\r',
#    'Praktikant/-in Altlasten\r',
#    'UX/UI Designer (w/m/d) 100%\r',
#    'Senior Java Developer in the field of Marketing Technology, Focus BSI Customer Suite\r',
#    '(Senior) Data scientist - AI & Machine Learning (f/m/d) 100%\r',
#    'Studierende/r HF/FH\r',
#    'Ökonom / Datenanalyst (w/m/d)\r',
#    'Praktikant*in Administration\r',
#    'Advanced Conversion Rate Optimization (CRO) Manager (f/m/d) 100%\r',
#    'l Python Backend Developer (incl. AWS/GCS Engineering) (f/m/d) 100%\r'],
#   ['Sparrow Ventures, Zürich\r',
#    'Sparrow Ventures, Zürich\r',
#    'Sorell Hotels, Zürich\r',
#    'Dynoptic Partner AG, Jona\r',
#    'Sorell Hotels, Zürich\r',
#    'Dynoptic Partner AG, Jona\r',
#    'Sorell Hotels, Zürich\r',
#    'Dynoptic Partner AG, Jona\r',
#    'Sunrise GmbH, Zurich\r',
#    'Sunrise GmbH, Zürich\r',
#    'Tamedia AG, Winterthur\r',
#    'Schweizerische Nationalbank, Zürich\r',
#    'BSH Hausgeräte AG, Geroldswil\r',
#    'Baudirektion Kanton Zürich, Zürich\r',
#    'Sunrise GmbH, Zurich (Headquarter)\r',
#    'Synpulse Schweiz AG, Zürich\r',
#    'Sunrise GmbH, Zürich\r',
#    'Tertianum AG, Winterthur\r',
#    'Fahrländer Partner Raumentwicklung, Zürich\r',
#    'Praktikant*in Content Creation\r',
#    'Praktikant*in Medienstelle & Community Management\r',
#    'Praktikant*in Social Media\r',
#    'PWA - Praktikant:in 100 %\r',
#    'Praktikum Diversity & Inclusion (40-60%)\r',
#    'ACCOUNTING TRAINEE 60-80% (M/W/D)\r',
#    'Praktikant/in Buchhaltung & Controlling 40-60%\r',
#    'Assistent/in Personal (befristet für 1 Jahr 50%)\r',
#    'Praktikant*in Social Media\r',
#    'Praktikant*in Medienstelle & Community Management\r',
#    'Praktikant*in Nachhaltigkeit\r',
#    'Praktikant*in Content Creation\r',
#    'Praktikum Diversity & Inclusion (40-60%)\r',
#    'PWA - Praktikant:in 100 %\r',
#    'ACCOUNTING TRAINEE 60-80% (M/W/D)\r',
#    'Praktikant/in Buchhaltung & Controlling 40-60%\r',
#    'Assistent/in Personal (befristet für 1 Jahr 50%)\r',
#    'Praktikant*in Medienstelle & Community Management\r',
#    'Praktikant*in Social Media\r',
#    'Praktikant*in Nachhaltigkeit\r',
#    'Praktikant*in Content Creation\r',
#    'Praktikum Diversity & Inclusion (40-60%)\r',
#    'PWA - Praktikant:in 100 %\r',
#    'ACCOUNTING TRAINEE 60-80% (M/W/D)\r',
#    'Praktikant/in Buchhaltung & Controlling 40-60%\r',
#    'Oberärztin / Oberarzt Nephrologie 80-100%\r',
#    'Assistent/in Personal (befristet für 1 Jahr 50%)\r',
#    'Internship Business Development\r',
#    'Praktikum Marketing und Kommunikation (w/m/d)\r',
#    'Praktikum Musikredaktion.\r',
#    'Master Data Specialist (m,w,d) 100%\r',
#    'Head of UX Design (m/f/d) 80-100 %\r',
#    'Ökonomen oder Juristen betreffend stationäre Tarife 80-100% (m/w)\r',
#    'Praktikant:in Product Management RED\r',
#    'Praktikant:in Sportredaktion / Content Creation\r',
#    'Senior Data Scientist (80-100%)\r',
#    'Grafik Designer mit Coding und Motion Skills\r',
#    'Web3 Praktikum.\r',
#    'Praktikant Supply Management (m/w)\r',
#    'Praktikum Praxisintegriertes Bachelor-Studium (PiBS) in Informatik (w/m/d)\r',
#    'Werkstudent:in Digital Business Ringier Advertising 50-100%\r'],
#   ['Digitec, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'ProPharma Systems AG, Wettingen AG\r',
#    'Vontobel, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'ZHAW, Winterthur\r',
#    'WSL, Birmensdorf\r',
#    'IVECO (Schweiz) AG, Kloten / Zürich\r',
#    'Kunsthaus Zürich, Zürich\r',
#    'Kunsthaus Zürich, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'WSL, Birmensdorf\r',
#    'ZHAW, Winterthur\r',
#    'IVECO (Schweiz) AG, Kloten / Zürich\r',
#    'Kunsthaus Zürich, Zürich\r',
#    'Kunsthaus Zürich, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'Migros-Genossenschafts-Bund, Zürich\r',
#    'WSL, Birmensdorf\r',
#    'ZHAW, Winterthur\r',
#    'IVECO (Schweiz) AG, Kloten / Zürich\r',
#    'Kunsthaus Zürich, Zürich\r',
#    'Universitätsspital Zürich, Zürich\r',
#    'Kunsthaus Zürich, Zürich\r',
#    'Givaudan, Kemptthal\r',
#    'Feller AG, Horgen\r',
#    'Energy Schweiz AG, Zürich\r',
#    'ASSA ABLOY (Schweiz) AG, Richterswil\r',
#    'JobCloud AG, Zürich\r',
#    'tarifsuisse ag, Zürich\r',
#    'Ringier Sports, Zürich\r',
#    'Ringier Sports, Zürich\r',
#    'Cembra Money Bank, Zürich\r',
#    'Digitec, Zürich\r',
#    'Energy Schweiz AG, Zürich\r',
#    'Sodexo (Suisse) SA, Glattbrugg\r',
#    'Swiss Life AG, Zürich\r',
#    'Ringier Advertising, Zürich-Altstetten\r']]}

# %% [markdown]
# ### "Special" For-Loop
#
# In order to create the dataset with the URL-infos, I needed to have a special for-loop, in order to **iterate only over every 3rd element (and by changing the starting point)**.
#
# As you can see below, this can be achieved via a **special slicing technique** (notice the `::` between the start-point "2" and end-point "3"? 😜)

# %%
list_of_df[2::3] # we iterate over every 3rd list (and start at the 3rd element // "2" element)
# check: are those the companies? --> yes!
# Out:
# [                       Wed, 4 Jan 2023 06:16:14 +0000
#  0               Migros-Genossenschafts-Bund, Zürich\r
#  1                                      KPMG, Zurich\r
#  2   Global IT-GITR, Deutschschweiz, Stadt Zürich /...
#  3                ProPharma Systems AG, Wettingen AG\r
#  4                                ETH Zürich, Zurich\r
#  5                               Sensirion AG, Stäfa\r
#  6                      Sensirion AG, Stäfa, Schweiz\r
#  7                           Concordia, Schaffhausen\r
#  8                          Sparrow Ventures, Zürich\r
#  9                              Biotronik AG, Bülach\r
#  10                             Biotronik AG, Bülach\r
#  11   Kantonale Verwaltung Zürich, Zürich Altstetten\r
#  12              Freestar-Informatik AG, Raum Zürich\r
#  13            Flughafen Zürich AG, Zürich-Flughafen\r
#  14                   Freestar-Informatik AG, Zürich\r
#  15            Flughafen Zürich AG, Zürich-Flughafen\r
#  16                Universitätsspital Zürich, Zürich\r
#  17                          Concordia, Schaffhausen\r
#  18                         Sparrow Ventures, Zürich\r
#  19                             Biotronik AG, Bülach\r
#  20                             Biotronik AG, Bülach\r
#  21   Kantonale Verwaltung Zürich, Zürich Altstetten\r
#  22              Freestar-Informatik AG, Raum Zürich\r
#  23            Flughafen Zürich AG, Zürich-Flughafen\r
#  24            Flughafen Zürich AG, Zürich-Flughafen\r
#  25                Universitätsspital Zürich, Zürich\r
#  26                   Freestar-Informatik AG, Zürich\r
#  27                          Concordia, Schaffhausen\r
#  28                         Sparrow Ventures, Zürich\r
#  29                             Biotronik AG, Bülach\r
#  30                             Biotronik AG, Bülach\r
#  31   Kantonale Verwaltung Zürich, Zürich Altstetten\r
#  32              Freestar-Informatik AG, Raum Zürich\r
#  33            Flughafen Zürich AG, Zürich-Flughafen\r
#  34                   Freestar-Informatik AG, Zürich\r
#  35            Flughafen Zürich AG, Zürich-Flughafen\r
#  36                Universitätsspital Zürich, Zürich\r
#  37                           tarifsuisse ag, Zürich\r
#  38  Threema GmbH, 8808 Pfäffikon SZ (Grossraum Zür...
#  39            Schweizer Radio und Fernsehen, Zürich\r
#  40                               Syntegon, Beringen\r
#  41                 Stadt Schaffhausen, Schaffhausen\r
#  42                                      EWZ, Zürich\r
#  43                                     KPMG, Zurich\r
#  44                                 Vontobel, Zürich\r
#  45                    Synechron Switzerland, Zürich\r
#  46  Stadt Zürich Gesundheitszentren für das Alter,...
#  47      Art of Work Personalberatung AG, Winterthur\r
#  48         HSO Wirtschaftsschule Schweiz AG, Zürich\r
#  49                               ETH Zürich, Zurich\r
#  50       VZ VermögensZentrum AG, Affoltern am Albis\r,
#                         Tue, 3 Jan 2023 05:51:23 +0000
#  0                          Sparrow Ventures, Zürich\r
#  1                          Sparrow Ventures, Zürich\r
#  2                             Sorell Hotels, Zürich\r
#  3                         Dynoptic Partner AG, Jona\r
#  4                             Sorell Hotels, Zürich\r
#  5                         Dynoptic Partner AG, Jona\r
#  6                             Sorell Hotels, Zürich\r
#  7                         Dynoptic Partner AG, Jona\r
#  8                              Sunrise GmbH, Zurich\r
#  9                              Sunrise GmbH, Zürich\r
#  10                           Tamedia AG, Winterthur\r
#  11              Schweizerische Nationalbank, Zürich\r
#  12                    BSH Hausgeräte AG, Geroldswil\r
#  13               Baudirektion Kanton Zürich, Zürich\r
#  14               Sunrise GmbH, Zurich (Headquarter)\r
#  15                      Synpulse Schweiz AG, Zürich\r
#  16                             Sunrise GmbH, Zürich\r
#  17                         Tertianum AG, Winterthur\r
#  18       Fahrländer Partner Raumentwicklung, Zürich\r
#  19  Stadt Zürich – Gesundheitszentren für das Alte...
#  20                          Sunrise GmbH, Glattpark\r
#  21                             Sunrise GmbH, Zürich\r,
#                         Mon, 2 Jan 2023 05:50:05 +0000
#  0                                    ROCKEN, Kloten\r
#  1                              ROCKEN, Spreitenbach\r
#  2                       Kessler.Vogler Gmbh, Zürich\r
#  3                                ETH Zürich, Zürich\r
#  4                    VZ VermögensZentrum AG, Meilen\r
#  5                       Kessler.Vogler Gmbh, Zürich\r
#  6                                ETH Zürich, Zürich\r
#  7                    VZ VermögensZentrum AG, Meilen\r
#  8                       Kessler.Vogler Gmbh, Zürich\r
#  9                                ETH Zürich, Zürich\r
#  10                   VZ VermögensZentrum AG, Meilen\r
#  11                        Energy Schweiz AG, Zürich\r
#  12                              JobCloud AG, Zürich\r
#  13           Swiss Finance & Property Group, Zürich\r
#  14  Liechtensteinische Landesbank AG, Eschen / Zür...
#  15           Ringier Advertising, Zürich-Altstetten\r
#  16                            DataVision AG, Zürich\r
#  17                        Energy Schweiz AG, Zürich\r
#  18                   BERTA Kommunikation AG, Zürich\r
#  19                         Sparrow Ventures, Zürich\r
#  20                        Cembra Money Bank, Zürich\r
#  21                   VZ VermögensZentrum AG, Zürich\r
#  22                Universitätsspital Zürich, Zürich\r
#  23  Liechtensteinische Landesbank AG, Eschen / Zür...
#  24                           Ringier Sports, Zürich\r,
#                        Sat, 31 Dec 2022 05:57:44 +0000
#  0                          Credit Suisse AG, Zürich\r
#  1                                       LGT, Zürich\r
#  2                          Credit Suisse AG, Zürich\r
#  3                                       LGT, Zürich\r
#  4                          Credit Suisse AG, Zürich\r
#  5                     Kantonspolizei Zürich, Zürich\r
#  6               Kantonale Verwaltung Zürich, Zürich\r
#  7   Bundesamt für Meteorologie und Klimatologie Me...
#  8               Kantonale Verwaltung Zürich, Zürich\r
#  9               Kantonale Verwaltung Zürich, Zürich\r
#  10                                Agroscope, Zürich\r
#  11                                gebana AG, Zürich\r
#  12  Bundesamt für Meteorologie und Klimatologie Me...
#  13              Kantonale Verwaltung Zürich, Zürich\r
#  14              Kantonale Verwaltung Zürich, Zürich\r
#  15                    Kantonspolizei Zürich, Zürich\r
#  16              Kantonale Verwaltung Zürich, Zürich\r
#  17                                Agroscope, Zürich\r
#  18                                gebana AG, Zürich\r
#  19              Kantonale Verwaltung Zürich, Zürich\r
#  20                    Kantonspolizei Zürich, Zürich\r
#  21  Bundesamt für Meteorologie und Klimatologie Me...
#  22              Kantonale Verwaltung Zürich, Zürich\r
#  23              Kantonale Verwaltung Zürich, Zürich\r
#  24                                Agroscope, Zürich\r
#  25                                gebana AG, Zürich\r
#  26                     Blick-Gruppe, Zürich-Seefeld\r
#  27         Schweizerische Südostbahn AG, Samstagern\r
#  28                          yellowshark® AG, Zürich\r
#  29                   Agroscope, Zürich-Affoltern ZH\r
#  30                              FE fundinfo, Zürich\r
#  31                            Glutz AG, Wallisellen\r
#  32                                   Assura, Zürich\r
#  33                        Renault Suisse SA, Urdorf\r
#  34                         Maerz Ofenbau AG, Zürich\r
#  35                     Stadt Winterthur, Winterthur\r
#  36                               Ratbacher AG, Bern\r
#  37                     Blick-Gruppe, Zürich-Seefeld\r
#  38              Ochsner Sport AG, Dietikon (Zürich)\r
#  39                     Stadt Winterthur, Winterthur\r,
#               Wed, 28 Dec 2022 06:10:27 +0000
#  0                          Digitec, Zürich\r
#  1      Migros-Genossenschafts-Bund, Zürich\r
#  2       ProPharma Systems AG, Wettingen AG\r
#  3                         Vontobel, Zürich\r
#  4      Migros-Genossenschafts-Bund, Zürich\r
#  5      Migros-Genossenschafts-Bund, Zürich\r
#  6      Migros-Genossenschafts-Bund, Zürich\r
#  7      Migros-Genossenschafts-Bund, Zürich\r
#  8                         ZHAW, Winterthur\r
#  9                         WSL, Birmensdorf\r
#  10     IVECO (Schweiz) AG, Kloten / Zürich\r
#  11                Kunsthaus Zürich, Zürich\r
#  12                Kunsthaus Zürich, Zürich\r
#  13     Migros-Genossenschafts-Bund, Zürich\r
#  14     Migros-Genossenschafts-Bund, Zürich\r
#  15     Migros-Genossenschafts-Bund, Zürich\r
#  16     Migros-Genossenschafts-Bund, Zürich\r
#  17                        WSL, Birmensdorf\r
#  18                        ZHAW, Winterthur\r
#  19     IVECO (Schweiz) AG, Kloten / Zürich\r
#  20                Kunsthaus Zürich, Zürich\r
#  21                Kunsthaus Zürich, Zürich\r
#  22     Migros-Genossenschafts-Bund, Zürich\r
#  23     Migros-Genossenschafts-Bund, Zürich\r
#  24     Migros-Genossenschafts-Bund, Zürich\r
#  25     Migros-Genossenschafts-Bund, Zürich\r
#  26                        WSL, Birmensdorf\r
#  27                        ZHAW, Winterthur\r
#  28     IVECO (Schweiz) AG, Kloten / Zürich\r
#  29                Kunsthaus Zürich, Zürich\r
#  30       Universitätsspital Zürich, Zürich\r
#  31                Kunsthaus Zürich, Zürich\r
#  32                     Givaudan, Kemptthal\r
#  33                       Feller AG, Horgen\r
#  34               Energy Schweiz AG, Zürich\r
#  35    ASSA ABLOY (Schweiz) AG, Richterswil\r
#  36                     JobCloud AG, Zürich\r
#  37                  tarifsuisse ag, Zürich\r
#  38                  Ringier Sports, Zürich\r
#  39                  Ringier Sports, Zürich\r
#  40               Cembra Money Bank, Zürich\r
#  41                         Digitec, Zürich\r
#  42               Energy Schweiz AG, Zürich\r
#  43          Sodexo (Suisse) SA, Glattbrugg\r
#  44                   Swiss Life AG, Zürich\r
#  45  Ringier Advertising, Zürich-Altstetten\r]

# %% [markdown]
# ### How do the separate DFs look like?
#
# To generate the DF with the URLs, I needed to merge some separate DFs together. This is how these separate DFs looked like...

# %%
url_df
# Out:
#                          Date  \
# 0   2023-01-04 06:16:14+00:00
# 1   2023-01-04 06:16:14+00:00
# 2   2023-01-04 06:16:14+00:00
# 3   2023-01-04 06:16:14+00:00
# 4   2023-01-04 06:16:14+00:00
# ..                        ...
# 179 2022-12-28 06:10:27+00:00
# 180 2022-12-28 06:10:27+00:00
# 181 2022-12-28 06:10:27+00:00
# 182 2022-12-28 06:10:27+00:00
# 183 2022-12-28 06:10:27+00:00
#
#                                                    url
# 0    https://www.jobs.ch/de/stellenangebote/detail/...
# 1    https://www.jobs.ch/de/stellenangebote/detail/...
# 2    https://www.jobs.ch/de/stellenangebote/detail/...
# 3    https://www.jobs.ch/de/stellenangebote/detail/...
# 4    https://www.jobs.ch/de/stellenangebote/detail/...
# ..                                                 ...
# 179  https://www.jobs.ch/de/stellenangebote/detail/...
# 180  https://www.jobs.ch/de/stellenangebote/detail/...
# 181  https://www.jobs.ch/de/stellenangebote/detail/...
# 182  https://www.jobs.ch/de/stellenangebote/detail/...
# 183  https://www.jobs.ch/de/stellenangebote/detail/...
#
# [184 rows x 2 columns]

# %%
title_df
# Out:
#                          Date  \
# 0   2023-01-04 06:16:14+00:00
# 1   2023-01-04 06:16:14+00:00
# 2   2023-01-04 06:16:14+00:00
# 3   2023-01-04 06:16:14+00:00
# 4   2023-01-04 06:16:14+00:00
# ..                        ...
# 179 2022-12-28 06:10:27+00:00
# 180 2022-12-28 06:10:27+00:00
# 181 2022-12-28 06:10:27+00:00
# 182 2022-12-28 06:10:27+00:00
# 183 2022-12-28 06:10:27+00:00
#
#                                              Job Title
# 0    Data Scientist - Optimierung Filialperformance...
# 1           Senior Manager – Lighthouse Data Science\r
# 2                 Scientist in Cell Line Development\r
# 3    Pharmabranche: Einstieg in die Software-Entwic...
# 4    Postdoctoral researcher in management and cont...
# ..                                                 ...
# 179     Grafik Designer mit Coding und Motion Skills\r
# 180                                  Web3 Praktikum.\r
# 181               Praktikant Supply Management (m/w)\r
# 182  Praktikum Praxisintegriertes Bachelor-Studium ...
# 183  Werkstudent:in Digital Business Ringier Advert...
#
# [184 rows x 2 columns]

# %%
company_df
# Out:
#                          Date  \
# 0   2023-01-04 06:16:14+00:00
# 1   2023-01-04 06:16:14+00:00
# 2   2023-01-04 06:16:14+00:00
# 3   2023-01-04 06:16:14+00:00
# 4   2023-01-04 06:16:14+00:00
# ..                        ...
# 179 2022-12-28 06:10:27+00:00
# 180 2022-12-28 06:10:27+00:00
# 181 2022-12-28 06:10:27+00:00
# 182 2022-12-28 06:10:27+00:00
# 183 2022-12-28 06:10:27+00:00
#
#                                       Employer Company
# 0                Migros-Genossenschafts-Bund, Zürich\r
# 1                                       KPMG, Zurich\r
# 2    Global IT-GITR, Deutschschweiz, Stadt Zürich /...
# 3                 ProPharma Systems AG, Wettingen AG\r
# 4                                 ETH Zürich, Zurich\r
# ..                                                 ...
# 179                                  Digitec, Zürich\r
# 180                        Energy Schweiz AG, Zürich\r
# 181                   Sodexo (Suisse) SA, Glattbrugg\r
# 182                            Swiss Life AG, Zürich\r
# 183           Ringier Advertising, Zürich-Altstetten\r
#
# [184 rows x 2 columns]

# %%
url_df
# Out:
#                          Date  \
# 0   2023-01-04 06:16:14+00:00
# 1   2023-01-04 06:16:14+00:00
# 2   2023-01-04 06:16:14+00:00
# 3   2023-01-04 06:16:14+00:00
# 4   2023-01-04 06:16:14+00:00
# ..                        ...
# 179 2022-12-28 06:10:27+00:00
# 180 2022-12-28 06:10:27+00:00
# 181 2022-12-28 06:10:27+00:00
# 182 2022-12-28 06:10:27+00:00
# 183 2022-12-28 06:10:27+00:00
#
#                                                    url
# 0    https://www.jobs.ch/de/stellenangebote/detail/...
# 1    https://www.jobs.ch/de/stellenangebote/detail/...
# 2    https://www.jobs.ch/de/stellenangebote/detail/...
# 3    https://www.jobs.ch/de/stellenangebote/detail/...
# 4    https://www.jobs.ch/de/stellenangebote/detail/...
# ..                                                 ...
# 179  https://www.jobs.ch/de/stellenangebote/detail/...
# 180  https://www.jobs.ch/de/stellenangebote/detail/...
# 181  https://www.jobs.ch/de/stellenangebote/detail/...
# 182  https://www.jobs.ch/de/stellenangebote/detail/...
# 183  https://www.jobs.ch/de/stellenangebote/detail/...
#
# [184 rows x 2 columns]
